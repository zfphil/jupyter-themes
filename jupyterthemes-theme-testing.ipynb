# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme
import jupyterthemes.stylefx as stylefx

# %% [markdown]
# ### Compile and Set Custom Theme

# %%
jt.install_theme('fresnel', cellwidth='95%')
set_nb_theme('fresnel')
# Out:
# fresnel
# styles/fresnel
# <style> fresnel@import "styles/fresnel";
# @container-margins: auto;
# @cell-width: 980px;
# @cc-line-height: 170%;
# @text-cell-bg: @cc-input-bg;
# @cc-prompt-width: 11.5ex;
# @cc-prompt-bg: @cc-input-bg;
# @cc-output-bg: @cc-output-bg-default;
# @prompt-text: @input-prompt;
# @prompt-padding: .25em;
# @prompt-border: 2px solid @prompt-line;
# @prompt-min-width: 11.5ex;
# @out-prompt-min-width: 11.5ex;
# @tc-prompt-width: 14.5ex;
# @tc-prompt-border: 2px solid @tc-prompt-std;
# @cursor-width: 2px;
# @cursor-info: @cursor-width solid default;
# @tc-prompt-fontsize: @prompt-fontsize;
#
#
# /*****************************************************************
#  Notebook stylization  (toolbars, lists, menus, scroll & buttons)
# *****************************************************************/
# div#notebook {
#     font-family: @notebook-fontfamily;
#     font-size: @nb-fontsize;
#     line-height: @cc-line-height;
#     color: @cc-input-fg;
# ...

# %%
jt.install_theme('fresnel')
set_nb_theme('fresnel')

import numpy as np
import matplotlib.pyplot as plt
jt.jtplot.style(grid=False)

plt.figure(figsize=(10,4))
plt.subplot(121)
plt.plot(np.random.rand(100))
plt.subplot(122)
plt.imshow(np.random.rand(100, 200))
# Out:
# fresnel
# styles/fresnel
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Uncomment and run cell to select a theme
# A Tall tall story
#
# $$ Ax = b $$

# %% [markdown]
# ### Test it out by writing some code
